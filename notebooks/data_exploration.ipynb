# %%
from pathlib import Path
from re import escape
import pandas as pd
from helpers.stock_data import clean_stock_data, impute_weekends

repo_root = Path().resolve().parent  # go up one level from notebooks/
file_path = repo_root / "data/processed/es_merged.csv"

data = pd.read_csv(file_path, index_col=0, parse_dates=True)

es_nan_count = data.isnull().sum()
print(es_nan_count)
# Out:
# day_ahead_price_eur_mwh    0
# load_forecast_mw           0
# solar_forecast_mw          0
# wind_aggr_mw               0
# price_d_1_h_eur_mwh        0
# price_d_2_h_eur_mwh        0
# price_d_7_h_eur_mwh        0
# price_d_1_24_eur_mwh       0
# price_d_1_min_eur_mwh      0
# price_d_1_max_eur_mwh      0
# co2_first_course_eur       0
# oil_first_course_eur       0
# gas_first_course_eur       0
# dtype: int64

# %%
from pathlib import Path
from re import escape
import pandas as pd
from helpers.stock_data import clean_stock_data, impute_weekends

repo_root = Path().resolve().parent  # go up one level from notebooks/
file_path = repo_root / "data/processed/ger_merged.csv"

data = pd.read_csv(file_path, index_col=0, parse_dates=True)

data.head()
# Out:
#                      day_ahead_price_eur_mwh  load_forecast_mw  \
# 2018-01-01 00:00:00                   -29.99        46139.5075
# 2018-01-01 01:00:00                   -56.65        44956.5850
# 2018-01-01 02:00:00                   -63.14        44586.4950
# 2018-01-01 03:00:00                   -64.62        44864.9650
# 2018-01-01 04:00:00                   -67.00        45111.7450
#
#                      solar_forecast_mw  wind_aggr_mw  price_d_1_h_eur_mwh  \
# 2018-01-01 00:00:00                0.0    33630.3425                -4.99
# 2018-01-01 01:00:00                0.0    34862.0525                -0.59
# 2018-01-01 02:00:00                0.0    35962.4750                -3.71
# 2018-01-01 03:00:00                0.0    36808.9250                 0.08
# 2018-01-01 04:00:00                0.0    37428.4700                 1.16
#
#                      price_d_2_h_eur_mwh  price_d_7_h_eur_mwh  \
# 2018-01-01 00:00:00                13.33               -32.58
# ...
